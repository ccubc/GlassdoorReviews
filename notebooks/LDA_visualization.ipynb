# %% [markdown]
# ## Visualize topics distribution for reviews on pros

# %%
import gensim
import pickle
import pyLDAvis
import pyLDAvis.gensim

# %%
# optimal number of topics for reviews on pros = 17, second-optimal number is 9
# will try 17 first and then 9
file = open('/Users/chengchen/glassdoor/model/lda_17_pro.pkl','rb')
lda_model = pickle.load(file)
file.close()
lda_model.print_topics()
# Out:
# [(0,
#   '0.097*"experience" + 0.060*"opportunity" + 0.054*"different" + 0.039*"technology" + 0.037*"lot" + 0.035*"company" + 0.034*"many" + 0.031*"world" + 0.031*"learning" + 0.029*"business"'),
#  (1,
#   '0.074*"management" + 0.071*"customer" + 0.048*"employee" + 0.044*"service" + 0.034*"sale" + 0.034*"manager" + 0.025*"community" + 0.021*"positive" + 0.018*"value" + 0.015*"store"'),
#  (2,
#   '0.299*"benefit" + 0.037*"health" + 0.036*"salary" + 0.035*"advancement" + 0.034*"bonus" + 0.030*"insurance" + 0.028*"employee" + 0.028*"competitive" + 0.026*"excellent" + 0.025*"package"'),
#  (3,
#   '0.144*"pay" + 0.079*"benefit" + 0.078*"decent" + 0.058*"time" + 0.046*"day" + 0.039*"hour" + 0.028*"vacation" + 0.028*"week" + 0.023*"money" + 0.022*"student"'),
#  (4,
#   '0.080*"people" + 0.070*"new" + 0.059*"thing" + 0.054*"amazing" + 0.035*"help" + 0.035*"willing" + 0.029*"awesome" + 0.028*"able" + 0.021*"group" + 0.021*"love"'),
#  (5,
# ...

# %%
file = open('/Users/chengchen/glassdoor/data/processed/review_pros_dic_mat.pkl', 'rb')
[dictionary, doc_term_matrix] = pickle.load(file)
file.close()
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, doc_term_matrix, dictionary)
vis
# Out:
# /Users/chengchen/anaconda/lib/python3.6/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=              x         y  topics  cluster      Freq
# topic
# 9      0.090599  0.205358       1        1  8.112476
# 15    -0.132567  0.030606       2        1  7.674341
# 1     -0.028075  0.089413       3        1  6.889161
# 11     0.002082 -0.052123       4        1  6.570204
# 7      0.092327  0.145518       5        1  6.547060
# 0      0.099344  0.227349       6        1  6.456374
# 4      0.140311 -0.119666       7        1  6.454894
# 3     -0.282688 -0.116144       8        1  6.346036
# 14    -0.099735 -0.023206       9        1  6.004123
# ...

# %%
# number_of_topics = 9
file = open('/Users/chengchen/glassdoor/model/lda_9_pro.pkl','rb')
lda_model = pickle.load(file)
file.close()
lda_model.print_topics()
# Out:
# [(0,
#   '0.051*"opportunity" + 0.051*"company" + 0.038*"project" + 0.030*"many" + 0.027*"different" + 0.025*"experience" + 0.025*"lot" + 0.024*"big" + 0.022*"large" + 0.021*"technology"'),
#  (1,
#   '0.118*"team" + 0.068*"management" + 0.052*"manager" + 0.044*"customer" + 0.041*"staff" + 0.029*"environment" + 0.022*"friendly" + 0.022*"employee" + 0.018*"member" + 0.017*"supportive"'),
#  (2,
#   '0.132*"benefit" + 0.065*"salary" + 0.059*"worker" + 0.053*"-" + 0.039*"co" + 0.030*"pro" + 0.029*"health" + 0.029*"competitive" + 0.026*"bonus" + 0.024*"insurance"'),
#  (3,
#   '0.091*"job" + 0.068*"pay" + 0.064*"hour" + 0.063*"flexible" + 0.061*"time" + 0.041*"benefit" + 0.035*"schedule" + 0.032*"easy" + 0.023*"decent" + 0.023*"day"'),
#  (4,
#   '0.034*"new" + 0.030*"people" + 0.021*"thing" + 0.020*"company" + 0.018*"year" + 0.017*"experience" + 0.016*"lot" + 0.012*"help" + 0.012*"skill" + 0.012*"time"'),
#  (5,
# ...

# %%
vis = pyLDAvis.gensim.prepare(lda_model, doc_term_matrix, dictionary)
vis
# Out:
# /Users/chengchen/anaconda/lib/python3.6/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 4      0.085713 -0.092521       1        1  17.885218
# 3     -0.235476  0.042626       2        1  13.434227
# 0      0.100176 -0.291483       3        1  10.894279
# 6      0.149805  0.235637       4        1  10.802850
# 5      0.065906 -0.110845       5        1  10.747299
# 7      0.043293 -0.164952       6        1  10.407961
# 1      0.177026  0.217615       7        1  10.309486
# 2     -0.364529  0.025151       8        1   8.051708
# ...

# %% [markdown]
# ## Visualize topics distribution for reviews on cons

# %%
# number_of_topics = 8
file = open('/Users/chengchen/glassdoor/model/lda_8_cons.pkl','rb')
lda_model = pickle.load(file)
file.close()
lda_model.print_topics()
# Out:
# [(0,
#   '0.043*"salary" + 0.039*"company" + 0.023*"slow" + 0.023*"year" + 0.022*"business" + 0.021*"change" + 0.020*"process" + 0.017*"low" + 0.016*"system" + 0.016*"market"'),
#  (1,
#   '0.047*"opportunity" + 0.040*"growth" + 0.038*"project" + 0.038*"much" + 0.036*"career" + 0.029*"lot" + 0.020*"advancement" + 0.018*"room" + 0.017*"politic" + 0.015*"limited"'),
#  (2,
#   '0.075*"company" + 0.056*"work" + 0.032*"environment" + 0.028*"great" + 0.027*"office" + 0.026*"good" + 0.025*"people" + 0.022*"thing" + 0.021*"place" + 0.019*"lot"'),
#  (3,
#   '0.047*"customer" + 0.040*"sale" + 0.034*"day" + 0.023*"time" + 0.019*"store" + 0.016*"month" + 0.016*"call" + 0.016*"service" + 0.013*"goal" + 0.012*"job"'),
#  (4,
#   '0.046*"employee" + 0.045*"manager" + 0.043*"people" + 0.041*"management" + 0.024*"company" + 0.021*"bad" + 0.015*"job" + 0.014*"good" + 0.014*"year" + 0.009*"none"'),
#  (5,
# ...

# %%
file = open('/Users/chengchen/glassdoor/data/processed/review_cons_dic_mat.pkl', 'rb')
[dictionary, doc_term_matrix] = pickle.load(file)
file.close()
vis = pyLDAvis.gensim.prepare(lda_model, doc_term_matrix, dictionary)
vis
# Out:
# /Users/chengchen/anaconda/lib/python3.6/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 4      0.087920  0.092383       1        1  20.032003
# 2     -0.039174 -0.187969       2        1  12.353427
# 7     -0.300205 -0.047173       3        1  12.282303
# 0      0.166112 -0.047887       4        1  12.202215
# 3     -0.220534  0.105876       5        1  11.982906
# 5      0.246398  0.029840       6        1  10.972165
# 6      0.014299  0.264791       7        1  10.407718
# ...

# %% [markdown]
# ## Draw word cloud of the topics (review_pros)

# %%
from matplotlib import pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors
from nltk.corpus import stopwords
# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline
stop_words = stopwords.words('english')
cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

# %%
cloud = WordCloud(stopwords=stop_words,
                  background_color='white',
                  width=1024,
                  height=720,
                  max_words=10,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = lda_model.show_topics(formatted=False)

fig, axes = plt.subplots(3, 3, figsize=(10,10), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
    plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Draw word cloud of the topics (review_cons)

# %%
file = open('/Users/chengchen/glassdoor/model/lda_8_cons.pkl','rb')
lda_model = pickle.load(file)
file.close()
topics = lda_model.show_topics(formatted=False)

fig, axes = plt.subplots(4, 2, figsize=(10,10), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
    plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %%
review_example = ["In 1863 Lincoln freed the slaves and in 1995 Jeff Bezos found a loop hole. He/Amazon offer you a droll worthy package that is impossible to turn down and after a few weeks of trying to figure out how to circumnavigate the behemoth company a switch is flipped and you feel like a slave everyday. I have worked for some of the most notorious sadist in NYC and none of them hold a candle to the managers that I have encountâ¦ ered during my year at Amazon. I am trying desperately to leave. I was hired for a job that was completely wrong for me and when I went to my manager I was told I wasn't allowed to transfer to a new division because my manager did not want to give someone else his problem. When I brought him 9 years worth of performance evaluations from my previous company where I was in the top 1% of employees he did not even look at it pushed it back at me and said ""I won't look at those because your previous employers standards are no where near Amazon's."" If they relocate you they hold a debt over your head equal to the price of a new Honda Civic. I belong to a support group of current and former employees who all have similar stories about being mistreated and emotionally abused.",
                  "I can find none."]
